# %% [markdown]
# <a href="https://colab.research.google.com/github/Son324/Practice/blob/main/DLW02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #😀 Installation, import libraries
# Topic[1]: API(Application Programming Interface)

# %% [markdown]
# ## Step 1 Install gTTS

# %%
# !pip install gTTS
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gTTS
#   Downloading gTTS-2.3.2-py3-none-any.whl (28 kB)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.10/dist-packages (from gTTS) (8.1.3)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from gTTS) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gTTS) (2.0.12)
# Installing collected packages: gTTS
# Successfully installed gTTS-2.3.2

# %% [markdown]
# ## Step 2 Import necessary libraries

# %%
from gtts import gTTS
from IPython.display import Audio

# %% [markdown]
# ## Step 3 Define tts(text)
# **def tts(text):**
#
# - This line defines a function called tts that takes a text argument. The purpose of this function is to convert the given text into an audio file.
#
# **gtts_object = gTTS(text,lang = "en", slow = True)**
#
# - This line creates a new gTTS object with the given text, specifying the language as English and the speech speed as slow.
#
# **gtts_object.save("myaudio.mp3")**
#
# - This line saves the audio file generated by the gTTS object to the file "myaudio.mp3" on the local filesystem.
#
# **return Audio("myaudio.mp3")**
#
# - This line returns an Audio object representing the audio file that was just saved. The Audio object can be used to play the audio file or manipulate it in various ways.

# %%
def tts(text):
  gtts_object = gTTS(text,lang = "en", slow = True) 
  gtts_object.save("myaudio.mp3")
  return Audio("myaudio.mp3")

# %%
tts('Hello students')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Step 4 Using Input ()

# %%
name = input("What is your name?: ")
# Out:
# What is your name?: Son

# %%
print(name)
# Out:
# Son

# %%
mytext = input("Type text to generate audio: ")

tts(mytext)
# Out:
# Type text to generate audio: Hello
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #😊 Variables

# %%
x = 10 #number
y = "Hello, class" #string
z = [1,2,3] #list

# %%
import pandas as pd
url = "https://github.com/MK316/Spring2023/raw/main/data/att_sample.csv"
data = pd.read_csv(url)
data

# %% [markdown]
# #🙂 Commenting '#'

# %%
x1 = x * 10
x2 = x + 5

print(x1, x2)
# Out:
# 100 15

# %%
y1 = y + "Welcome to the class"
z1 = z + [3,2,1]

print(y1, z1)
# Out:
# Hello, classWelcome to the class [1, 2, 3, 3, 2, 1]

# %% [markdown]
# #😃 Operators
# ---
# integer: -3, 1, 0, etc.
#
# string: "1", "Mary", "euphoria", etc.

# %%
x = 2
y = 5

a1 = x + y
a2 = x - y
a3 = x * y
a4 = x / y
a5 = x ** y

# %%
print(a1, a2, a3, a4, a5)
# Out:
# 7 -3 10 0.4 32

# %%
print("The value of a1: ", a1)
# Out:
# The value of a1:  7

# %%
def add(x, y): return x + y
def subtract(x, y): return x - y
def multiply(x, y): return x * y
def divide(x, y): return x / y

# %%
add(2,3)
#subtract(2,3)
#multiply(2,3)
#divide(2,3)
# Out:
# 5

# %%
x = 1
y = 3
z = x + y
print(z)

x1 = "1"
y1 = "3"
z1 = x1 + y1
print(z1)
# Out:
# 4
# 13

# %%
print(type(z))
print(type(z1))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# DLW02d의 'Using dropbox format'은 나중에

# %%
a = [1, "Mary", 4, "John"]
type(a)
print(type(a))

a[0]
type(a[0])
type(a[1])
a[0] + a[2] #integer끼리라서 덧셈가능 type(a[0] + a[2])
# a[0] + a[1] #integer + string = error
# Out:
# <class 'list'>
# 5
