# %% [markdown]
# <a href="https://colab.research.google.com/github/Son324/Practice/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

def etts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", slow = True)
  text = "Hello"
  etts(text)
  Audio("E-audio.mp3", autoplay = True)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # 🐷 YouTubeVideo display

# %%
# !pip install gTTS
from gtts import gTTS
from IPython.display import YouTubeVideo #Audio, Image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
video = YouTubeVideo("ey4H7BY5CAI", wid = 800)
display(video)

# %% [markdown]
# # 🧑 Learn coding to handle string data

# %%
# 1. 문자열이란?
"Life is too short, You need Python"
"a"
"123"
# Out:
# '123'

# %%
# 2.1. 문자열 안에 작은 따옴표나 큰 따옴표를 포함시키고 싶을 때
food = "Python's favorite food is perl"
food

say = '"Python is very easy." he says.'
say

food = 'Python\s favorite food is perl'
say = "\"Python is very easy.\" he says." 
say
#\(백슬래시)를 작은따옴표, 큰따옴표 앞에 삽입하면, 
#뒤의 작은따옴표나 큰따옴표는 문자열을 둘러싸는 기호 의미가 아니라 문자 그 자체
# Out:
# '"Python is very easy." he says.'

# %%
# 2.2. 여러 줄인 문자열을 변수에 대입하고 싶을 때
#multiline = "Life is too short\nYou need Python"

multiline = """
Life is too short
You need Python
"""
print(multiline)
# Out:
# Life is too short
# You need Python

# %%
# 2.3. 이스케이프 코드란?

# %% [markdown]
# \n:	문자열 안에서 줄을 바꿀 때 사용
#
# \t:	문자열 사이에 탭 간격을 줄 때 사용
#
# \\:	문자 \를 그대로 표현할 때 사용
#
# \':	작은따옴표(')를 그대로 표현할 때 사용
#
# \":	큰따옴표(")를 그대로 표현할 때 사용
#
# \r:	캐리지 리턴(줄 바꿈 문자, 현재 커서를 가장 앞으로 이동)
#
# \f:	폼 피드(줄 바꿈 문자, 현재 커서를 다음 줄로 이동)
#
# \a:	벨 소리(출력할 때 PC 스피커에서 '삑' 소리가 난다)
#
# \b:	백 스페이스
#
# \000:	널 문자

# %%
# 3.1. 문자열 더해서 연결하기
head = "Python"
tail = " is fun!"
head + tail
# Out:
# 'Python is fun!'

# %%
# 3.2. 문자열 곱하기
a = "Python"
a * 2
# Out:
# 'PythonPython'

# %%
# 3.3. 문자열 곱하기 응용
#multistring.py

print("=" * 50)
print("My Program")
print("=" * 50)

#입력한 소스는 C:\doit 디렉터리에 파일 이름 multistring.py로 저장
# [윈도우 + R(실행) → cmd 입력 → Enter]를 눌러 명령 프롬프트 창
# 그럼 C:\Users>cd C:\doit; C:\doit>python multistring.py
# Out:
# ...
# My Program
# ...

# %%
# 3.4. 문자열 길이 구하기
a = "Life is too short"
len(a)
# Out:
# 17

# %%
# 4.1. 문자열 인덱싱이란?
#인덱싱(Indexing): 가리킨다
#슬라이싱(Slicing): 잘라낸다

a = "Life is too short, You need Python"
a[3] #a[번호]: 문자열 안의 특정한 값을 뽑아내는 역할 = indexing
# Out:
# 'e'

# %%
# 4.2. 문자열 인덱싱 활용하기
a = "Life is too short, You need Python"
a[0]
a[12]
a[-1]
a[-2]
a[-5]
# Out:
# 'y'

# %%
# 4.3. 문자열 슬라이싱이란?
a = "Life is too short, You need Python"
b = a[0] + a[1] + a[2] + a[3]
b

a[0:4] #a[시작 번호:끝 번호]일 때 끝 번호는 포함하지 않음
# Out:
# 'Life'

# %%
# 4.4. 문자열을 슬라이싱하는 방법
a = "Life is too short, You need Python"
a[0:5] #공백 문자 역시 문자와 동일하게 취급   #'Life'와 'Life '는 완전히 다른 문자열
a[5:7]
a[12:17]
a[19:]
a[:17]
a[:]
a[19:-7]
# Out:
# 'You need'

# %%
# 4.5. 슬라이싱으로 문자열 나누기
a = "20010331Rainy"
date = a[:8]
date
year = a[:4]
year
day = a[4:8]
day
weather = a[8:]
weather
# Out:
# 'Rainy'

# %%
# <"Pithon"이라는 문자열을 "Python"으로 바꾸려면?>
a = "Pithon"
a[:1] # P
a[2:] # thon
a[:1] + "y" + a[2:]
# Out:
# 'Python'

# %%
# 5.1. 문자열 포매팅 따라하기
# 문자열 안의 특정한 값을 바꿔야 할 경우가 있을 때 가능하게 해주는 것
"I eat %d apples." % 3   # %d는 %가 숫자일 때
"I eat %s apples." % "five"   # %s는 %가 문자열일 때

number = 3
"I eat %d apples." % number

number = 10
day = "three"
"I ate %d apples. So I was sick for %s days." %(number, day)

"I have %d apples." % 3
"I have %f apples." % 3.234
#근데 여기서 %s는 뒤에 정수나 소수 다 사용 가능 --> 이유는 뒤에 있는 값을 문자열로 취급
"I have %s apples." % 3.234
# Out:
# 'I have 3.234 apples.'

# %% [markdown]
# %s:	문자열(String)
#
# %d:	정수(Integer)
#
# %f:	부동소수(floating-point)

# %%
# %d와 %가 같은 문자열 안에 존재하는 경우, %를 나타내려면 반드시 %%로 써야 함
# 문자열 안에 %d와 같은 포매팅 연산자가 없으면 %는 홀러 쓰여도 상관 없음

"Error is %d%%" % 98

number = 98
"Error is %d%%" % number
# Out:
# 'Error is 98%'

# %% [markdown]
# # ⭐ Quiz

# %%
mytext1 = "We are the group number 5."
mytext2 = "We're the group number 5."
mytext3 = 'We are the group number "5".'

# %%
print(mytext1)
print(mytext2)
print(mytext3)
# Out:
# We are the group number 5.
# We're the group number 5.
# We are the group number "5".

# %%
# Print the 8th string in 'mytext2'.
mytext2[7]
# Out:
# 'h'

# %%
# In mytext2, print strings from the 7th to the 15th.
mytext2[6:15]
# Out:
# 'the group'

# %%
print(mytext1 + mytext2 + mytext3)
# Out:
# We are the group number 5.We're the group number 5.We are the group number "5".

# %%
a = "Bravo!"
b = "Group 5"
a + " " + b
# Out:
# 'Bravo! Group 5'

# %%
len(mytext1)
# Out:
# 26

# %%
sample = "I love fireworks"
print(sample[2] + sample[8] + sample[7] + sample[5])
# Out:
# life

# %%
sample = "I love fireworks"
print(sample[-14] + sample[-8] + sample[-9] + sample[-11])
# Out:
# life

# %%
sample = "I love fireworks"

w1 = sample[0]
w2 = sample[2:6]
w3 = sample[7:]
print(w1, w2, w3)
# Out:
# I love fireworks

# %%
a = "my gruop"

a[:5] + "ou" + a[7:]
# Out:
# 'my group'
