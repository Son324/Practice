# %% [markdown]
# <a href="https://colab.research.google.com/github/Son324/Practice/blob/main/Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 😊 Wordcloud

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# 텍스트 입력
text = input("Please paste your text here: ")
#(text = "" 바로 작성해도 됨)

# WordCloud 객체 생성
wordcloud = WordCloud(
    background_color='white',
    width=800,
    height=800,
    ).generate(text)

# WordCloud 이미지 생성
plt.figure(figsize=(8, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# Please paste your text here: In the summer of 1889, Vincent van Gogh arrived as a voluntary patient at the asylum of Saint-Paul-de-Mausole, in Saint-Rémy. His recuperation from a series of breakdowns was overseen by a team of doctors, but the artist had a self-prescribed remedy. It was to engage with nature and embroil himself deeper with his art. And he became increasingly fixated with one feature of the surrounding Provençal countryside: its muscular, ancient cypress trees.  Van Gogh's Cypresses, a new exhibition at the Metropolitan Museum of Art in New York, puts the spotlight on the tree that became the artist's obsession. "This is the first exhibition to focus on Van Gogh's cypresses," its curator Susan Alyson Stein, tells BBC Culture. "It is an unprecedented and entirely new perspective. It reveals the back story behind his long-standing interest in the motif."  Here's what four key artworks in the exhibition reveal about Van Gogh's symbol of resilience.

# %% [markdown]
# # 😊 gTTS

# %%
# !pip install gtts
from gtts import gTTS
from IPython.display import Audio, display

def tts(txt):
  tts = gTTS(txt, lang='en', slow = True)
  tts.save("myaudio.mp3")
  return Audio("myaudio.mp3")

mytext = input("Type text: ")
tts(mytext)

# 다양한 text 입력 방법
# tts('Hello students')
# mytext = input("Type text to generate audio: ")
# tts(mytext)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Type text: Hello
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 😊 Random Function

# %%
import random
random.randint(1,10)

# a1 = random.randint(1,10)
# a1*10
# Out:
# 20

# %%
a1 = random.randint(1,10)
print("Random integer between 1 and 10: ", a1)
# Out:
# Random integer between 1 and 10:  9

# %% [markdown]
# # 😊 Integers and String

# %%
day = input("How many days: ") #day = string 일 때
num_day = int(day) #day를 integer로 바꿈
hours = 24
total = num_day * hours
print("The total hours passed since Mary met John are: ", total, "hours.")

day = input("How many days: ")
num_day = int(day)
minutes = 1440
total1 = num_day * minutes
print("The total minutes passed since Mary met John are: ", total1, "minutes.")
# Out:
# How many days: 5
# The total hours passed since Mary met John are:  120 hours.
# How many days: 5
# The total minutes passed since Mary met John are:  7200 minutes.

# %%
# day = input("How many days: ") # day는 string
# num_day = int(day) # day를 num_day로 바꾸면서 --> string을 integer로 바꿈
# hours = 24 # hour는 integer
# total = num_day * hours
# print("The total hours passed since Mary met John are: ", total, "hours.")
# Out:
# The total hours passed since Mary met John are:  72 hours.

# %% [markdown]
# # 😊 Dictionary Datatype

# %%
mydict = {"API": "Application Programming Interface"}
mydict["API"]

mydict = {"GPT": "Generative Pretrained Transformer"}
mydict["GPT"]

class_size = {"Class A": 25, "Class B": 30, "Class C": 32}
class_size["Class C"]

# mydict = {"Name": "Son Yeonwoo", "Age": 21}
# Out:
# str

# %% [markdown]
# # 😊 Strip / Split / Join

# %%
w1 = " Mary is friendly. "
w1
w1.strip() # strip은 문자열 앞뒤 공백 제거
# Out:
# 'Mary is friendly.'

# %%
w1 = "Mary is friendly."
w1.split() # split은 공백을 기준으로 문자열을 단어로 분할하여 리스트
# Out:
# ['Mary', 'is', 'friendly.']

# %%
m1 = "Mary"
m2 = "is"
m3 = "friendly"

wordlist = [m1, m2, m3]
wordlist

' '.join(wordlist)
# Out:
# 'Mary is friendly'

# %%
m1.lower()
m1.upper()
# Out:
# 'MARY'

# %% [markdown]
# # 😊 Yes - No Question

# %%
m1 = "Mary"; m2 = "is"; m3 = "friendly."
capital = m2[0].upper() + m2[1:]

sentence = capital + " " + m1 + " " + m3
sentence1 = sentence[:-1] # sentence에서 "." 빼고 나옴
sentence2 = sentence1 + "?" # sentence1에서 뒤에 "?" 붙임
sentence2

# w1은 w1 = input("Write a sentence: ") 해도 됨
w1 = "Mary is friendly."
a = w1.split()
m1 = a[0]
m2 = a[1]
m3 = a[2]

cap = m2[0].upper() + m2[1:]

s = cap + " " + m1 + " " + m3

s1 = s[:-1] # s에서 "." 뺀 것
s2 = s1 + "?" # s1에서 뒤에 "?" 붙임
s2
# Out:
# 'Is Mary friendly?'

# %% [markdown]
# # 😊 Control structures: for loops, while loops, and conditional statement

# %%
number = 2
print(number ** 2)
# Out:
# 4

# %%
numbers = [1,2,3,4,5]
for num in numbers:
  print(num ** 2)

numbers = [1,2,3]
for num in numbers:
  s = num ** 2
  print(s)


# 여기서 둘의 차이는 'for num in numbers:' 를 하여 numbers 리스트에 있는 것들 요소로 하나씩 가져옴
# 그리고 가져오 것을 num이라 하는데 그걸 2제곱한 것을 또 s로 둠
# 그리고 마지막에 간단하게 print(num ** 2)라고 하지 않고, print(s)로 둠
# Out:
# 1
# 4
# 9
# 16
# 25
# 1
# 4
# 9

# %%
numbers = [1,2,3,4,5]
squared = [] # 빈 리스트인 squared를 생성하여 제곱한 결과 저장할 준비함

for i in numbers:
  s = i ** 2 # 현재 반복되고 있는 i 값을 제곱하여 변수 's'로 지정
  squared.append(s) # 변수 's' 값을 'squared' 리스트에 추가
print(squared)
# Out:
# [1, 4, 9, 16, 25]

# %%
num_names = input("How many names? ")
num_names = int(num_names) #string을 integer로 바꿈

attendance = []

for i in range(0, num_names):
  name = input()
  attendance.append(name)

print(attendance)
# Out:
# How many names? 3
# Harry
# John
# Biden
# ['Harry', 'John', 'Biden']

# %% [markdown]
# # 😊 YoutubeVideo Display

# %%
# !pip install gTTS
from gtts import gTTS
from IPython.display import YouTubeVideo #Audio, Image


video = YouTubeVideo("ey4H7BY5CAI", wid = 800)
display(video)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # 😊 QR Display

# %%
# 'pyqrcode' 라이브러리를 pip를 사용하여 설치
# !pip install pyqrcode

# 'pyqrcode'와 'QRCode' 모듈을 가져옴
import pyqrcode
from pyqrcode import QRCode

# 사용자로부터 링크를 입력받음
s = input("Paste the link: ")

# 'pyqrcode.create()' 함수를 사용하여 입력받은 링크로부터 QR 코드 객체를 생성
url = pyqrcode.create(s)

# 'url.svg("myqrcode.svg", scale=10)' 사용하여 QR코드를 SVG파일로 저장 / 'myqrcode.svg'는 저장할 파일의 이름
url.svg("myqrcode.svg", scale=10)

# 'IPython.display' 모듈에서 'SVG'와 'dksplay'를 가져옴
from IPython.display import SVG, display
def show_svg(file):
    display(SVG(file))

# 'show_svg("myqrcode.svg")' 호출하여 SVG 파일을 표시
show_svg("myqrcode.svg")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Paste the link: https://github.com/MK316/Spring2023/blob/main/QRcode.ipynb

# %% [markdown]
# # 😊 Tokenize by words or sentences
# Tokenize: 단어를 하나씩 나누기 (=split)

# %%
example_string = "My name is Sarah. I live in a big city. I like to read books and play with my cat."

# space 기준으로 split
set1 = example_string.split()
print(set1)

# "." 기준으로 split
set2 = example_string.split(".")
print(set2)
# 0번째는 My name is Sarah
# 1번째는 (space 포함) I live in a big city
# 2번째는 (space 포함) I like to read books and play with my cat
# 3번째는 아무것도 없는 string
# Out:
# ['My', 'name', 'is', 'Sarah.', 'I', 'live', 'in', 'a', 'big', 'city.', 'I', 'like', 'to', 'read', 'books', 'and', 'play', 'with', 'my', 'cat.']
# ['My name is Sarah', ' I live in a big city', ' I like to read books and play with my cat', '']

# %%
# Strip / 공백을 제거

# set2의 각 요소에 대해 양쪽의 공백 제거 후, set3을 생성하는 코드
# 각 요소를 (My name is Sarah / I live in a big city 등) 변수 's'에 할당
# for은 주어진 리스트, 튜플, 집합 등의 반복 가능한 객체를 순회하면서 각 요소에 대해 정해진 작업 수행 가능하도록 함
# 밑의 코드에서는 set2 리스트의 각 요소를 s 변수에 할당하고, 반복문의 내부 블록 안에서 s를 사용
set3 = [s.strip() for s in set2]
set3
# 교수님 say, [ ] 표현식은 s라는 자료를 strip, for(~에 대하여, 여기서는 s에 대해서, se2에 있는 문장들을 한 줄로 process)
# set2의 s를 strip(0번째, 1번째, ...)
# Out:
# ['My name is Sarah',
#  'I live in a big city',
#  'I like to read books and play with my cat',
#  '']

# %%
# for in 이해 위해 연습
fruit = [' apple ', ' banana ', ' cherry ']

for s in fruit:
  print(s)
# Out:
#  apple
#  banana
#  cherry

# %%
# set3 리스트 요소 중 빈 문자열이 아닌 것들로 새로운 리스트 set4 생성
# set3 리스트의 각 요소에 대해 조건문 'x != ""' 적용 --> x가 빈 문자열이 아닌 경우에만 해당
# 이러한 조건을 만족하는 값들로 구성된 새로운 리스트를 생성하여 set4에 할당
set4 = [x for x in set3 if x != ""]
set4
# 교수님 say, x를 set4에 넣어라, x는 set3에 있는 문장들
# if (만약에) x가 !=(~가 아니면), ==(~가 일치하면)

# %%
# 빈 문자열이 아닌 요소들만 추려져서 새로운 리스트 생성 (특정 조건을 만족하는 요소들로 구성됨)
# 빈 문자열을 필터링하여 fruit3 요소 중에서 유효한 값들로 구성된 fruit4 리스트 만듦
fruit3 = ['apple', 'banana', '', 'cherry','']

fruit4 = [x for x in fruit3 if x != ""]
fruit4
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# # 😊 Using {nltk} library

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
# sent_tokenize는 함수 이름, 그대로 써야함 (belongs to natural language processing libraries such as NLTK)

# %%
# %%capture
slist = sent_tokenize(example_string)
slist[2]

# %%
mytext=input("Paste text: ")
slist1 = sent_tokenize(mytext)
slist1

len(slist1) # slist1 길이 확인하고 싶을 때

mywords = word_tokenize(mytext)
print(len(mywords))
mywords

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# [1] Getting word frequency

# %%
# word_tokenize: separating punctuation as individual word items
words = word_tokenize(text)

# Without punctuation:
wordlist = []

for w in words:
  if len(w) > 2:
    wordlist.append(w)

print('Total words including punctuation: ', len(words))
print('Total words: ', len(wordlist))
print(wordlist)

# %%
# Lower case
lowerword = []

for w in wordlist:
  w1 = w.lower()
  lowerword.append(w1)
print(lowerword)

words = lowerword
print("Word size before stopwords: ", len(words))

# %%
# Stop words to remove

from nltk.corpus import stopwords
nltk.download('stopwords')
print("Word size before stopwords: ", len(words))
print(words)

print("="*50)
words2 = [w for w in words if w not in stopwords.words('english')]
print(words2)
print("Word size after removing stopwords: ", len(words2))

# %%
fd = nltk.FreqDist(words2)
fd
print('Word type: %d'%len(fd),'개')

fwords = nltk.FreqDist(words2).most_common()
print(fwords[:5])

# %%
# One time occurrences:
freq_num1 = [item[1] for item in fwords]
num1 = freq_num1.count(1);
print('Number of words that occur only once: %d'%num1)
print('The rest: %d'%(213-num1))

# nth word that occurs more than 2
i=0
for n in freq_num1:
  if n >2:
#    print(n)
    i += 1
print('몇 번째 단어까지 2회 초과 빈도? %d'%i, '번째')

# %%
# Words that occur more than twice
fwords = nltk.FreqDist(words2).most_common(20)
fwords

# %% [markdown]
# # 😊 Filtering stopwords

# %% [markdown]
# **Stopwords**
#
# Stop words are words that you want to ignore, so you filter them out of your text when you’re processing it. Very common words like 'in', 'is', and 'an' are often used as stop words since they don’t add a lot of meaning to a text in and of themselves.
#
# Here’s how to import the relevant parts of NLTK in order to filter out stop words:

# %% [markdown]
# # 😊 API, GPT, NLP, NLTK

# %% [markdown]
# ### API: Application Programming Interface
# ### GPT: Generative Pretrained Transformer
# ### NLP: Natural Language Processing
# ### NLTK: Natural Language ToolKit

# %% [markdown]
# # 😊 Gradio

# %%
# %%capture
# !pip install gradio

import gradio as gr

def greet(name):
    return "Hello " + name + "!"

demo = gr.Interface(fn=greet, inputs="text", outputs="text")

demo.launch()

# %% [markdown]
# ## [1] D-day counting with Gradio implementation

# %%
# %%capture
# !pip install gradio

import gradio as gr
from datetime import datetime

def remaining_days(future_date: str):
    # Try to convert string to datetime object
    try:
        future_date = datetime.strptime(future_date, '%Y-%m-%d')
    except ValueError:
        return "Invalid date format. Please use 'YYYY-MM-DD'"

    # Get current date
    current_date = datetime.now()

    # Calculate remaining days
    remaining = future_date - current_date
    return remaining.days

iface = gr.Interface(fn=remaining_days,
                     inputs=gr.inputs.Textbox(label="Input a future date (YYYY-MM-DD)"),
                     outputs="number")
iface.launch(share=True)

# %% [markdown]
# ## [2] TTS implementation

# %%
# %%capture
# !!pip install gTTS

import gradio as gr
from gtts import gTTS
from pydub import AudioSegment
import os

def text_to_speech(text):
    tts = gTTS(text=text, lang='en')
    mp3_filename = "voice.mp3"
    wav_filename = "voice.wav"
    tts.save(mp3_filename)

    # Convert from MP3 to WAV
    audio = AudioSegment.from_mp3(mp3_filename)
    audio.export(wav_filename, format="wav")

    return wav_filename

iface = gr.Interface(fn=text_to_speech,
                     inputs=gr.inputs.Textbox(),
                     outputs=gr.outputs.Audio(type="filepath"))
iface.launch(share=True)

# %% [markdown]
# ## [3] Grade checher

# %%
# !pip install pandas faker

import pandas as pd
import random

# The 10 most popular baby names
popular_baby_names = ["Liam", "Emma", "Noah", "Olivia", "Ava", "Isabella", "Sophia", "Mia", "Charlotte", "Amelia"]

# Create lists for the data
names = popular_baby_names
english_grades = [random.randint(0, 100) for _ in range(10)]
math_grades = [random.randint(0, 100) for _ in range(10)]

# Create a DataFrame
df = pd.DataFrame({
    'Name': names,
    'English': english_grades,
    'Math': math_grades,
})

print(df)

# %%
# !pip install gradio

import gradio as gr

def check_grades(name):
    name = name.strip().lower()  # remove extra white spaces and convert to lower case
    df['Name'] = df['Name'].str.strip().str.lower()  # do the same for names in DataFrame
    if name in df['Name'].values:
        english_grade = df.loc[df['Name'] == name, 'English'].values[0]
        math_grade = df.loc[df['Name'] == name, 'Math'].values[0]
        return f"English Grade: {english_grade}, Math Grade: {math_grade}"
    else:
        return "Name not found in the DataFrame."


iface = gr.Interface(fn=check_grades,
                     inputs=gr.inputs.Textbox(lines=1, placeholder='Enter a name...'),
                     outputs="text")
iface.launch()

# %% [markdown]
# # 😊 Midterm Review

# %% [markdown]
# Q8. Create a list called colors and add three of your favorite colors to it. Use the join() function to join the list into a string separated by commas. Then, print the string.

# %%
colors = ['Red', 'Blue', 'Green']

','.join(colors)
# Out:
# 'Red,Blue,Green'

# %% [markdown]
# Q13. Create a list called numbers. Using the random.randint() function, add five random integers to it. Then, print the list.
# Note: You should not write the random number on your own. The code should take the random number and add it to your list.

# %%
import random

numbers = []

for _ in range(5):
    random_number = random.randint(1, 100)
    numbers.append(random_number)

print(numbers)
# Out:
# [30, 45, 95, 20, 31]

# %%
animal_list = ["dog", "cat", "pig"]

for a in animal_list:
  print("I love " + a + "!")
# Out:
# I love dog!
# I love cat!
# I love pig!

# %%
fruit_dict = {'apple': 'red', 'banana': 'yellow', 'orange': 'orange'}
fruit_dict["banana"]
# Out:
# 'yellow'

# %%
my_string = "apple,banana,orange"
my_list = my_string.split(",")
print(my_list)
# Out:
# ['apple', 'banana', 'orange']

# %% [markdown]
# Q20. Create a language application that changes a declarative sentence to an imperative sentence. Test the app with the following sentences:
# "You take your seat." > (output) Take your seat!
# "You bring your book." > (output) Bring your book!
# Step1. Start with the first sentence, and add code lines in order to get the output ('Take your seat!')
# Step2. Make another code cell and make a user interactive app using input(). Here you should be able to get the output of the second sentence when the user type the second sentence.

# %%
# Declarative sentence
sentence = "You take your seat."

# Split the sentence into words
words = sentence.split()   # ['You', 'take', 'your', 'seat.']

w1 = words[0]
w2 = words[1]
w3 = words[2]
w4 = words[3]

cap = w2[0].upper() + w2[1:]

# Remove the pronoun "You" from the sentence
#imperative_sentence = " ".join(words[1:])   # take your seat.

sentence = cap + " " + w3 + " " + w4
sentence1 = sentence[:-1]
sentence2 = sentence1 + "!"
print(sentence2)

# Add an exclamation mark at the end
#imperative_sentence += "!"

# Print the imperative sentence
#print(imperative_sentence)
# Out:
# Take your seat!

# %%
# User interactive app
sentence = input("Type your sentence: ")

# Split the sentence into words
words = sentence.split()

# Remove the pronoun from the sentence
imperative_sentence = " ".join(words[1:])

# Add an exclamation mark at the end
imperative_sentence += "!"

# Print the imperative sentence
print(imperative_sentence)
